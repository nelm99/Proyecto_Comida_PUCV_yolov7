# %% [markdown]
# # Exploracion de archivos

# %% [markdown]
# ### Estructura del directorio

# %%
import os

path_carpeta = 'data/desordenadas/'
path_final = 'data/juntas/'

for folder in os.listdir(path_carpeta):
    folder_path = os.path.join(path_carpeta, folder)
    if os.path.isdir(folder_path):
        print(folder)
        for subfolder in os.listdir(folder_path):
            subfolder_path = os.path.join(folder_path, subfolder)
            if os.path.isdir(subfolder_path):
                print(f"  {subfolder}")
                for subsubfolder in os.listdir(subfolder_path):
                    subsubfolder_path = os.path.join(subfolder_path, subsubfolder)
                    if os.path.isdir(subsubfolder_path):
                        print(f"    {subsubfolder}")
# Out:
# 2023-11-09.v4i.yolov7pytorch
#   test
#     images
#     labels
#   train
#     images
#     labels
#   valid
#     images
#     labels
# 2023-11-10.v2i.yolov7pytorch
#   test
#     images
#     labels
#   train
#     images
#     labels
#   valid
#     images
#     labels
# 2023-11-13.v2i.yolov7pytorch
#   test
#     images
#     labels
#   train
#     images
#     labels
#   valid
#     images
#     labels
# 2023-11-14.v7i.yolov7pytorch
#   test
#     images
#     labels
#   train
#     images
#     labels
#   valid
#     images
#     labels
# 2023-11-15.v1i.yolov7pytorch
#   test
#     images
#     labels
#   train
#     images
#     labels
#   valid
#     images
#     labels
# 2023-11-16.v4i.yolov7pytorch
#   test
#     images
#     labels
#   train
#     images
#     labels
#   valid
#     images
#     labels
# 2023-11-17.v1i.yolov7pytorch
#   test
#     images
#     labels
#   train
#     images
#     labels
#   valid
#     images
#     labels

# %% [markdown]
# ### Cantidad de imagenes/etiquetas por carpeta

# %%
import os

path_carpeta = 'data/desordenadas/'

for folder in os.listdir(path_carpeta):
    folder_path = os.path.join(path_carpeta, folder)
    if os.path.isdir(folder_path):
        print(f"\nCarpeta: {folder}")
        for subfolder in os.listdir(folder_path):
            subfolder_path = os.path.join(folder_path, subfolder)
            if os.path.isdir(subfolder_path):
                print(f"  Subcarpeta: {subfolder}")
                images_path = os.path.join(subfolder_path, 'images')
                labels_path = os.path.join(subfolder_path, 'labels')

                if os.path.exists(images_path) and os.path.exists(labels_path):
                    num_images = len([name for name in os.listdir(images_path) if os.path.isfile(os.path.join(images_path, name))])
                    num_labels = len([name for name in os.listdir(labels_path) if os.path.isfile(os.path.join(labels_path, name))])

                    print(f"    Número de imágenes en {subfolder}/images: {num_images}")
                    print(f"    Número de etiquetas en {subfolder}/labels: {num_labels}")
# Out:
# Carpeta: 2023-11-09.v4i.yolov7pytorch
#   Subcarpeta: test
#     Número de imágenes en test/images: 153
#     Número de etiquetas en test/labels: 153
#   Subcarpeta: train
#     Número de imágenes en train/images: 3436
#     Número de etiquetas en train/labels: 3436
#   Subcarpeta: valid
#     Número de imágenes en valid/images: 64
#     Número de etiquetas en valid/labels: 64
#
# Carpeta: 2023-11-10.v2i.yolov7pytorch
#   Subcarpeta: test
#     Número de imágenes en test/images: 202
#     Número de etiquetas en test/labels: 202
#   Subcarpeta: train
#     Número de imágenes en train/images: 1926
#     Número de etiquetas en train/labels: 1926
#   Subcarpeta: valid
#     Número de imágenes en valid/images: 101
#     Número de etiquetas en valid/labels: 101
#
# Carpeta: 2023-11-13.v2i.yolov7pytorch
#   Subcarpeta: test
#     Número de imágenes en test/images: 17
#     Número de etiquetas en test/labels: 17
#   Subcarpeta: train
#     Número de imágenes en train/images: 209
#     Número de etiquetas en train/labels: 209
#   Subcarpeta: valid
#     Número de imágenes en valid/images: 8
#     Número de etiquetas en valid/labels: 8
#
# Carpeta: 2023-11-14.v7i.yolov7pytorch
#   Subcarpeta: test
#     Número de imágenes en test/images: 309
#     Número de etiquetas en test/labels: 309
#   Subcarpeta: train
#     Número de imágenes en train/images: 1227
#     Número de etiquetas en train/labels: 1227
#   Subcarpeta: valid
#     Número de imágenes en valid/images: 196
#     Número de etiquetas en valid/labels: 196
#
# Carpeta: 2023-11-15.v1i.yolov7pytorch
#   Subcarpeta: test
#     Número de imágenes en test/images: 147
#     Número de etiquetas en test/labels: 147
#   Subcarpeta: train
#     Número de imágenes en train/images: 1444
#     Número de etiquetas en train/labels: 1444
#   Subcarpeta: valid
#     Número de imágenes en valid/images: 67
#     Número de etiquetas en valid/labels: 67
#
# Carpeta: 2023-11-16.v4i.yolov7pytorch
#   Subcarpeta: test
#     Número de imágenes en test/images: 188
#     Número de etiquetas en test/labels: 188
#   Subcarpeta: train
#     Número de imágenes en train/images: 981
#     Número de etiquetas en train/labels: 981
#   Subcarpeta: valid
#     Número de imágenes en valid/images: 104
#     Número de etiquetas en valid/labels: 104
#
# Carpeta: 2023-11-17.v1i.yolov7pytorch
#   Subcarpeta: test
#     Número de imágenes en test/images: 32
#     Número de etiquetas en test/labels: 32
#   Subcarpeta: train
#     Número de imágenes en train/images: 311
#     Número de etiquetas en train/labels: 311
#   Subcarpeta: valid
#     Número de imágenes en valid/images: 20
#     Número de etiquetas en valid/labels: 20

# %% [markdown]
# ### Funcion que unifica todos los archivos

# %%
import os
import shutil

def merge_folders(root_path, root_destino, subfolder_names):
    # Crear las carpetas de destino si no existen
    destination_folders = {name: os.path.join(root_destino, name) for name in subfolder_names}
    for dest_folder in destination_folders.values():
        os.makedirs(dest_folder, exist_ok=True)
        # Crear subcarpetas 'images' y 'labels'
        os.makedirs(os.path.join(dest_folder, 'images'), exist_ok=True)
        os.makedirs(os.path.join(dest_folder, 'labels'), exist_ok=True)

    # Recorrer cada carpeta de fecha
    date_folders = [f for f in os.listdir(root_path) if os.path.isdir(os.path.join(root_path, f))]

    for date_folder in date_folders:
        for subfolder_name in subfolder_names:
            # Ruta de la subcarpeta actual
            current_subfolder_path = os.path.join(root_path, date_folder, subfolder_name)

            # Dividir en imágenes y etiquetas
            for subsubfolder_name in ['images', 'labels']:
                subsubfolder_path = os.path.join(current_subfolder_path, subsubfolder_name)
                if os.path.exists(subsubfolder_path):
                    # Copiar todos los archivos de esta subcarpeta a la carpeta de destino correspondiente
                    for filename in os.listdir(subsubfolder_path):
                        src_file = os.path.join(subsubfolder_path, filename)
                        dst_file = os.path.join(destination_folders[subfolder_name], subsubfolder_name, filename)
                        shutil.copy2(src_file, dst_file)

root_dir = 'data/desordenadas/'  # Cambia esto por la ruta de tu directorio
root_dir_destino = 'data/juntas/'
subfolders = ['train', 'test', 'val']
merge_folders(root_dir, root_dir_destino, subfolders)

# %% [markdown]
# ### Cantidad de imágenes y etiquetas en cada carpeta unificada

# %%
import os

path_carpeta = 'data/juntas/'

for folder in os.listdir(path_carpeta):
    folder_path = os.path.join(path_carpeta, folder)
    if os.path.isdir(folder_path):
        print(f"\nCarpeta: {folder}")
        images_path = os.path.join(folder_path, 'images')
        labels_path = os.path.join(folder_path, 'labels')

        if os.path.exists(images_path) and os.path.exists(labels_path):
            num_images = len([name for name in os.listdir(images_path) if os.path.isfile(os.path.join(images_path, name))])
            num_labels = len([name for name in os.listdir(labels_path) if os.path.isfile(os.path.join(labels_path, name))])

            print(f"  Número de imágenes en {folder}/images: {num_images}")
            print(f"  Número de etiquetas en {folder}/labels: {num_labels}")
# Out:
# Carpeta: test
#   Número de imágenes en test/images: 1048
#   Número de etiquetas en test/labels: 1048
#
# Carpeta: train
#   Número de imágenes en train/images: 9534
#   Número de etiquetas en train/labels: 9534
#
# Carpeta: val
#   Número de imágenes en val/images: 560
#   Número de etiquetas en val/labels: 560

# %% [markdown]
# # Data Cleaning

# %%
import os

path_carpeta = 'data/desordenadas/2023-11-17.v1i.yolov7pytorch/'

mapeo_carpeta = {
    '0':'6',
    '1':'0',
    '2':'23',
    '3':'21',
    '4':'5',
    '5':'13',
}

# %%
# funcion para actualizar las etiquetas de clase
def actualizar_etiquetas(lineas, mapeo_clases):
    etiquetas_actualizadas = []
    for linea in lineas:
        partes = linea.strip().split()
        if partes:
            clase_original = partes[0]
            if clase_original in mapeo_clases:
                partes[0] = mapeo_clases[clase_original]
            etiqueta_actualizada = ' '.join(partes)
            etiquetas_actualizadas.append(etiqueta_actualizada + '\n')
    return etiquetas_actualizadas

# %%
# funcion para abrir - actualizar - cerrar un archivo
vacias = {}
for folder in os.listdir(path_carpeta):
    folder_path = os.path.join(path_carpeta, folder)
    if os.path.isdir(folder_path):
        print(f"Carpeta: {folder}")
        images_path = os.path.join(folder_path, 'images')
        labels_path = os.path.join(folder_path, 'labels')
        for filename in os.listdir(labels_path):

            with open(os.path.join(labels_path, filename), 'r') as f:
                lines = f.readlines()
            
            if not lines:
                if folder not in vacias:
                    vacias[folder] = []
                vacias[folder].append(filename)
                continue

            etiquetas_actualizadas = actualizar_etiquetas(lines, mapeo_carpeta)

            with open(os.path.join(labels_path, filename), 'w') as f:
                f.writelines(etiquetas_actualizadas)
# Out:
# Carpeta: test
# Carpeta: train
# Carpeta: valid

# %%
# delete empty files
for folder in vacias:
    for filename in vacias[folder]:
        print(f"Eliminando {filename.replace('.txt', '')} de {folder} en labels e images en {path_carpeta}")
        os.remove(os.path.join(path_carpeta, folder, 'labels', filename))
        os.remove(os.path.join(path_carpeta, folder, 'images', filename.replace('.txt', '.jpg')))
# Out:
# Eliminando ch01_131000000_010_jpg.rf.077aa6e7ac1ea3d9ad9ad42a34398636 de test en labels e images en data/desordenadas/2023-11-17.v1i.yolov7pytorch/
# Eliminando ch01_131000000
#   'ch01_131000000_030_jpg.rf.e96b88d7f6177fa20fca20fd38542689.txt',
#   'ch01_131000000_030_jpg.rf.feeb165c7efb71a320cc5423bc0f707b.txt',
#   'ch01_131000000_039_jpg.rf.29103f9fca7b44a981f8e93a4e37777f.txt',
#   'ch01_131000000_039_jpg.rf.d4c83d162710aab4e1ead088d9442857.txt',
#   'ch01_131000000_039_jpg.rf.f2268c013ad3de289149660f5e9fef83.txt',
#   'ch01_131000000_041_jpg.rf.6189dfbc82b8dc808337393e0191bb17.txt',
#   'ch01_131000000_041_jpg.rf.7b5c4d547d11bc8292da30a86511b427.txt',
#   'ch01_131000000_041_jpg.rf.cce7fe7dd1a2fa55642092f0b0293953.txt',
#   'ch01_131000000_055_jpg.rf.07938832119bf7732174d311a7def4f9.txt',
#   'ch01_131000000_055_jpg.rf.10e0aa3c4cd2c4612d8ef9837ed2c3fa.txt',
#   'ch01_131000000_055_jpg.rf.97708ce4a0553dd140fc97bd2a74f0a6.txt',
#   'ch01_133000000_003_jpg.rf.3d5d27e82bcdb23ceddbc3a2d61f06c2.txt',
#   'ch01_133000000_003_jpg.rf.e89912b40c373c9f0357e3c23a57721e.txt',
#   'ch01_133000000_003_jpg.rf.f9c91f59167a13c1fb9ade1c51a4cb3b.txt'],
#  'valid': ['ch01_128000000_001_jpg.rf.c5348db4308af2afaaa44ae0b9730767.txt',
#   'ch01_130000000_034_jpg.rf.7920d0e7594e61044d974340130f7ba3.txt',
#   'ch01_131000000_009_jpg.rf.b1fbeb2cd09cef87c3dc0c035ec4b29a.txt',
#   'ch01_131000000_015_jpg.rf.254bd779e9ae7b95d876d27fbdd9a859.txt',
#   'ch01_131000000_018_jpg.rf.219617968b27c97796214b111dc55572.txt',
#   'ch01_131000000_022_jpg.rf.f12df9d29f07329651225f19838171b3.txt',
#   'ch01_131000000_023_jpg.rf.fed80e2233d12d718fc3c1391cc0d123.txt',
#   'ch01_131000000_034_jpg.rf.88f99111783c5fca77a323ea6d2f4de5.txt',
#   'ch01_131000000_044_jpg.rf.4c139c4d6c1eeefee18571c3c92f8578.txt',
#   'ch01_131000000_045_jpg.rf.929463a375308748a11691b253f730f9.txt',
#   'ch01_131000000_053_jpg.rf.c17d5b1d2f4594eae0ea575a7edae94d.txt',
#   'ch01_131000000_057_jpg.rf.05091df0896db054aa38c037252afbbd.txt']}

# %% [markdown]
# # Revisar carpeta YOLO

# %%
import os

def revisar_carpeta_yolo(path_base):
    for tipo in ['train', 'val', 'test']:
        carpeta_images = os.path.join(path_base, tipo, 'images')
        carpeta_labels = os.path.join(path_base, tipo, 'labels')
        verificar_duplicados = [f for f in os.listdir(carpeta_labels) if f.endswith('.txt')]

        archivos_images = {f.split('.')[0] for f in os.listdir(carpeta_images) if f.endswith(('.jpg', '.png'))}
        archivos_labels = {f.split('.')[0] for f in os.listdir(carpeta_labels) if f.endswith('.txt')}

        # Verificar si cada imagen tiene su correspondiente archivo de etiqueta
        for archivo in archivos_images:
            if archivo not in archivos_labels:
                print(f"Falta archivo de etiqueta para la imagen {archivo} en {tipo}")
        
        for archivo in archivos_labels:
            if archivo not in archivos_images:
                print(f"Falta imagen para el archivo de etiqueta {archivo} en {tipo}")

        # Verificar duplicados
        for archivo in verificar_duplicados:
            ruta_archivo = os.path.join(carpeta_labels, archivo)
            with open(ruta_archivo, 'r') as f:
                lineas = f.read().splitlines()

            if len(lineas) != len(set(lineas)):
                print(f'Etiquetas duplicadas encontradas en {ruta_archivo}')



path_base = 'data/juntas'
revisar_carpeta_yolo(path_base)

# %%
import os
from collections import defaultdict

def contar_etiquetas_por_clase(path_base, nombres_clases):
    contador_clases = defaultdict(int)
    
    for tipo in ['train', 'val', 'test']:
        carpeta_labels = os.path.join(path_base, tipo, 'labels')
        
        # Contar etiquetas por clase
        for archivo_label in os.listdir(carpeta_labels):
            if archivo_label.endswith('.txt'):
                ruta_archivo_label = os.path.join(carpeta_labels, archivo_label)
                with open(ruta_archivo_label, 'r') as f:
                    for linea in f:
                        if linea.strip():  # Asegurarse de que la línea no esté vacía
                            clase = int(linea.split()[0])  # Convertir a entero para obtener el índice de la clase
                            nombre_clase = nombres_clases[clase]  # Obtener el nombre de la clase
                            contador_clases[nombre_clase] += 1

    # Ordenar clases por conteo de menor a mayor
    clases_ordenadas = sorted(contador_clases.items(), key=lambda item: item[1])

    # Imprimir conteo por clase ordenado
    for nombre_clase, conteo in clases_ordenadas:
        print(f'Clase {nombre_clase}: {conteo} etiquetas')

# Nombres de las clases según su índice
nombres_clases = ['Bandeja', 'Carne de cerdo', 'Chorizo', 'Fideos', 'Garbanzos', 'Plato', 'Arroz', 'Hamburguesa', 
                  'Carne molida', 'Budin de verduras', 'Ensaladas', 'Pescado frito', 'Pollo arvejado', 'Pollo asado', 
                  'Huevo', 'Charquican', 'Lentejas', 'Pure', 'Vienesas', 'Porotos', 'Tallarines', 'Papas fritas', 
                  'Estofado de carne', 'Carne']

# Ruta base donde se encuentran las carpetas 'train', 'val', 'test'
path_base = 'data/juntas'
contar_etiquetas_por_clase(path_base, nombres_clases)
# Out:
# Clase Budin de verduras: 39 etiquetas
# Clase Chorizo: 39 etiquetas
# Clase Garbanzos: 46 etiquetas
# Clase Huevo: 80 etiquetas
# Clase Charquican: 95 etiquetas
# Clase Carne: 116 etiquetas
# Clase Ensaladas: 160 etiquetas
# Clase Vienesas: 165 etiquetas
# Clase Carne de cerdo: 235 etiquetas
# Clase Fideos: 237 etiquetas
# Clase Papas fritas: 343 etiquetas
# Clase Pescado frito: 453 etiquetas
# Clase Carne molida: 479 etiquetas
# Clase Tallarines: 514 etiquetas
# Clase Lentejas: 725 etiquetas
# Clase Estofado de carne: 733 etiquetas
# Clase Porotos: 750 etiquetas
# Clase Hamburguesa: 911 etiquetas
# Clase Pollo arvejado: 1061 etiquetas
# Clase Pure: 1155 etiquetas
# Clase Pollo asado: 1796 etiquetas
# Clase Arroz: 4406 etiquetas
# Clase Plato: 7522 etiquetas
# Clase Bandeja: 8339 etiquetas
